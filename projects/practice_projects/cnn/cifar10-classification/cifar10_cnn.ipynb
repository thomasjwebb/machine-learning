# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,095,786
# Trainable params: 1,095,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 69s - loss: 1.6166 - acc: 0.4177 - val_loss: 1.3324 - val_acc: 0.5354
#
# Epoch 00001: val_loss improved from inf to 1.33240, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 64s - loss: 1.2870 - acc: 0.5400 - val_loss: 1.4864 - val_acc: 0.4910
#
# Epoch 00002: val_loss did not improve from 1.33240
# Epoch 3/100
#  - 65s - loss: 1.1829 - acc: 0.5850 - val_loss: 1.3377 - val_acc: 0.5362
#
# Epoch 00003: val_loss did not improve from 1.33240
# Epoch 4/100
#  - 66s - loss: 1.1423 - acc: 0.6021 - val_loss: 1.2024 - val_acc: 0.5710
#
# Epoch 00004: val_loss improved from 1.33240 to 1.20243, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 59s - loss: 1.1143 - acc: 0.6152 - val_loss: 1.1408 - val_acc: 0.6610
#
# Epoch 00005: val_loss improved from 1.20243 to 1.14084, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 53s - loss: 1.1154 - acc: 0.6148 - val_loss: 1.2318 - val_acc: 0.6198
#
# Epoch 00006: val_loss did not improve from 1.14084
# Epoch 7/100
#  - 59s - loss: 1.1147 - acc: 0.6187 - val_loss: 1.3924 - val_acc: 0.6006
#
# Epoch 00007: val_loss did not improve from 1.14084
# Epoch 8/100
#  - 62s - loss: 1.1184 - acc: 0.6171 - val_loss: 1.4490 - val_acc: 0.5904
#
# Epoch 00008: val_loss did not improve from 1.14084
# Epoch 9/100
#  - 54s - loss: 1.1217 - acc: 0.6178 - val_loss: 1.3467 - val_acc: 0.5448
#
# Epoch 00009: val_loss did not improve from 1.14084
# Epoch 10/100
#  - 59s - loss: 1.1226 - acc: 0.6212 - val_loss: 1.4029 - val_acc: 0.5846
#
# Epoch 00010: val_loss did not improve from 1.14084
# Epoch 11/100
#  - 53s - loss: 1.1379 - acc: 0.6164 - val_loss: 1.3521 - val_acc: 0.6094
#
# Epoch 00011: val_loss did not improve from 1.14084
# Epoch 12/100
#  - 54s - loss: 1.1442 - acc: 0.6160 - val_loss: 1.3862 - val_acc: 0.5496
#
# Epoch 00012: val_loss did not improve from 1.14084
# Epoch 13/100
#  - 56s - loss: 1.1559 - acc: 0.6088 - val_loss: 1.3253 - val_acc: 0.6180
#
# Epoch 00013: val_loss did not improve from 1.14084
# Epoch 14/100
#  - 55s - loss: 1.1655 - acc: 0.6076 - val_loss: 1.0809 - val_acc: 0.6662
#
# Epoch 00014: val_loss improved from 1.14084 to 1.08086, saving model to model.weights.best.hdf5
# Epoch 15/100
#  - 66s - loss: 1.1672 - acc: 0.6100 - val_loss: 1.0344 - val_acc: 0.6812
#
# Epoch 00015: val_loss improved from 1.08086 to 1.03442, saving model to model.weights.best.hdf5
# Epoch 16/100
#  - 59s - loss: 1.1816 - acc: 0.6036 - val_loss: 1.4025 - val_acc: 0.5546
#
# Epoch 00016: val_loss did not improve from 1.03442
# Epoch 17/100
#  - 75s - loss: 1.1856 - acc: 0.6016 - val_loss: 1.5340 - val_acc: 0.5248
#
# Epoch 00017: val_loss did not improve from 1.03442
# Epoch 18/100
#  - 58s - loss: 1.1990 - acc: 0.5993 - val_loss: 1.2720 - val_acc: 0.6308
#
# Epoch 00018: val_loss did not improve from 1.03442
# Epoch 19/100
#  - 56s - loss: 1.2016 - acc: 0.5934 - val_loss: 1.4379 - val_acc: 0.5384
#
# Epoch 00019: val_loss did not improve from 1.03442
# Epoch 20/100
#  - 52s - loss: 1.2157 - acc: 0.5892 - val_loss: 1.0799 - val_acc: 0.6402
#
# Epoch 00020: val_loss did not improve from 1.03442
# Epoch 21/100
#  - 55s - loss: 1.2148 - acc: 0.5914 - val_loss: 1.1525 - val_acc: 0.6372
#
# Epoch 00021: val_loss did not improve from 1.03442
# Epoch 22/100
#  - 53s - loss: 1.2285 - acc: 0.5898 - val_loss: 1.6996 - val_acc: 0.4170
#
# Epoch 00022: val_loss did not improve from 1.03442
# Epoch 23/100
#  - 52s - loss: 1.2391 - acc: 0.5832 - val_loss: 1.1635 - val_acc: 0.6190
#
# Epoch 00023: val_loss did not improve from 1.03442
# Epoch 24/100
#  - 52s - loss: 1.2513 - acc: 0.5816 - val_loss: 1.3304 - val_acc: 0.5794
#
# Epoch 00024: val_loss did not improve from 1.03442
# Epoch 25/100
#  - 51s - loss: 1.2532 - acc: 0.5779 - val_loss: 1.2676 - val_acc: 0.5950
#
# Epoch 00025: val_loss did not improve from 1.03442
# Epoch 26/100
#  - 50s - loss: 1.2586 - acc: 0.5786 - val_loss: 1.4530 - val_acc: 0.5258
#
# Epoch 00026: val_loss did not improve from 1.03442
# Epoch 27/100
#  - 50s - loss: 1.2641 - acc: 0.5755 - val_loss: 1.4195 - val_acc: 0.6030
#
# Epoch 00027: val_loss did not improve from 1.03442
# Epoch 28/100
#  - 50s - loss: 1.2676 - acc: 0.5704 - val_loss: 1.5426 - val_acc: 0.5398
#
# Epoch 00028: val_loss did not improve from 1.03442
# Epoch 29/100
#  - 50s - loss: 1.2768 - acc: 0.5687 - val_loss: 1.3372 - val_acc: 0.5754
#
# Epoch 00029: val_loss did not improve from 1.03442
# Epoch 30/100
#  - 49s - loss: 1.2951 - acc: 0.5659 - val_loss: 1.4526 - val_acc: 0.5408
#
# Epoch 00030: val_loss did not improve from 1.03442
# Epoch 31/100
#  - 48s - loss: 1.3030 - acc: 0.5594 - val_loss: 1.2297 - val_acc: 0.6388
#
# Epoch 00031: val_loss did not improve from 1.03442
# Epoch 32/100
#  - 48s - loss: 1.3058 - acc: 0.5582 - val_loss: 1.6443 - val_acc: 0.4260
#
# Epoch 00032: val_loss did not improve from 1.03442
# Epoch 33/100
#  - 48s - loss: 1.3040 - acc: 0.5588 - val_loss: 1.2125 - val_acc: 0.6294
#
# Epoch 00033: val_loss did not improve from 1.03442
# Epoch 34/100
#  - 48s - loss: 1.3069 - acc: 0.5543 - val_loss: 1.6691 - val_acc: 0.4378
#
# Epoch 00034: val_loss did not improve from 1.03442
# Epoch 35/100
#  - 49s - loss: 1.3155 - acc: 0.5532 - val_loss: 1.3975 - val_acc: 0.5528
#
# Epoch 00035: val_loss did not improve from 1.03442
# Epoch 36/100
#  - 49s - loss: 1.3309 - acc: 0.5506 - val_loss: 1.4752 - val_acc: 0.5282
#
# Epoch 00036: val_loss did not improve from 1.03442
# Epoch 37/100
#  - 49s - loss: 1.3326 - acc: 0.5472 - val_loss: 1.4356 - val_acc: 0.5448
#
# Epoch 00037: val_loss did not improve from 1.03442
# Epoch 38/100
#  - 49s - loss: 1.3329 - acc: 0.5484 - val_loss: 1.3658 - val_acc: 0.5648
#
# Epoch 00038: val_loss did not improve from 1.03442
# Epoch 39/100
#  - 49s - loss: 1.3392 - acc: 0.5434 - val_loss: 1.5639 - val_acc: 0.4552
#
# Epoch 00039: val_loss did not improve from 1.03442
# Epoch 40/100
#  - 49s - loss: 1.3501 - acc: 0.5377 - val_loss: 1.2843 - val_acc: 0.5548
#
# Epoch 00040: val_loss did not improve from 1.03442
# Epoch 41/100
#  - 49s - loss: 1.3472 - acc: 0.5401 - val_loss: 1.3240 - val_acc: 0.5788
#
# Epoch 00041: val_loss did not improve from 1.03442
# Epoch 42/100
#  - 49s - loss: 1.3552 - acc: 0.5389 - val_loss: 1.2805 - val_acc: 0.5874
#
# Epoch 00042: val_loss did not improve from 1.03442
# Epoch 43/100
#  - 49s - loss: 1.3550 - acc: 0.5395 - val_loss: 1.6585 - val_acc: 0.4216
#
# Epoch 00043: val_loss did not improve from 1.03442
# Epoch 44/100
#  - 49s - loss: 1.3554 - acc: 0.5385 - val_loss: 1.5188 - val_acc: 0.4892
#
# Epoch 00044: val_loss did not improve from 1.03442
# Epoch 45/100
#  - 49s - loss: 1.3600 - acc: 0.5347 - val_loss: 2.0843 - val_acc: 0.2218
#
# Epoch 00045: val_loss did not improve from 1.03442
# Epoch 46/100
#  - 60s - loss: 1.3669 - acc: 0.5304 - val_loss: 1.5909 - val_acc: 0.4672
#
# Epoch 00046: val_loss did not improve from 1.03442
# Epoch 47/100
#  - 80s - loss: 1.3633 - acc: 0.5329 - val_loss: 1.2991 - val_acc: 0.5542
#
# Epoch 00047: val_loss did not improve from 1.03442
# Epoch 48/100
#  - 56s - loss: 1.3893 - acc: 0.5247 - val_loss: 1.5845 - val_acc: 0.4500
#
# Epoch 00048: val_loss did not improve from 1.03442
# Epoch 49/100
#  - 59s - loss: 1.3840 - acc: 0.5274 - val_loss: 1.8422 - val_acc: 0.3574
#
# Epoch 00049: val_loss did not improve from 1.03442
# Epoch 50/100
#  - 62s - loss: 1.3820 - acc: 0.5266 - val_loss: 1.2954 - val_acc: 0.5616
#
# Epoch 00050: val_loss did not improve from 1.03442
# Epoch 51/100
#  - 54s - loss: 1.3915 - acc: 0.5243 - val_loss: 1.4045 - val_acc: 0.5452
#
# Epoch 00051: val_loss did not improve from 1.03442
# Epoch 52/100
#  - 51s - loss: 1.4004 - acc: 0.5225 - val_loss: 1.2329 - val_acc: 0.6020
#
# Epoch 00052: val_loss did not improve from 1.03442
# Epoch 53/100
#  - 55s - loss: 1.4045 - acc: 0.5204 - val_loss: 1.3225 - val_acc: 0.5624
#
# Epoch 00053: val_loss did not improve from 1.03442
# Epoch 54/100
#  - 52s - loss: 1.3951 - acc: 0.5241 - val_loss: 1.7458 - val_acc: 0.3808
#
# Epoch 00054: val_loss did not improve from 1.03442
# Epoch 55/100
#  - 66s - loss: 1.4088 - acc: 0.5183 - val_loss: 1.4904 - val_acc: 0.4856
#
# Epoch 00055: val_loss did not improve from 1.03442
# Epoch 56/100
#  - 59s - loss: 1.4215 - acc: 0.5142 - val_loss: 1.5117 - val_acc: 0.4890
#
# Epoch 00056: val_loss did not improve from 1.03442
# Epoch 57/100
#  - 66s - loss: 1.4324 - acc: 0.5084 - val_loss: 1.4075 - val_acc: 0.5030
#
# Epoch 00057: val_loss did not improve from 1.03442
# Epoch 58/100
#  - 57s - loss: 1.4249 - acc: 0.5130 - val_loss: 1.3517 - val_acc: 0.5480
#
# Epoch 00058: val_loss did not improve from 1.03442
# Epoch 59/100
#  - 64s - loss: 1.4371 - acc: 0.5114 - val_loss: 1.3960 - val_acc: 0.5398
#
# Epoch 00059: val_loss did not improve from 1.03442
# Epoch 60/100
#  - 59s - loss: 1.4345 - acc: 0.5084 - val_loss: 1.3888 - val_acc: 0.5338
#
# Epoch 00060: val_loss did not improve from 1.03442
# Epoch 61/100
#  - 72s - loss: 1.4485 - acc: 0.5038 - val_loss: 1.4408 - val_acc: 0.5222
#
# Epoch 00061: val_loss did not improve from 1.03442
# Epoch 62/100
#  - 62s - loss: 1.4401 - acc: 0.5057 - val_loss: 1.4261 - val_acc: 0.5254
#
# Epoch 00062: val_loss did not improve from 1.03442
# Epoch 63/100
#  - 57s - loss: 1.4521 - acc: 0.5028 - val_loss: 1.3402 - val_acc: 0.5696
#
# Epoch 00063: val_loss did not improve from 1.03442
# Epoch 64/100
#  - 55s - loss: 1.4673 - acc: 0.4962 - val_loss: 1.4023 - val_acc: 0.4992
#
# Epoch 00064: val_loss did not improve from 1.03442
# Epoch 65/100
#  - 54s - loss: 1.4718 - acc: 0.4954 - val_loss: 1.3816 - val_acc: 0.5406
#
# Epoch 00065: val_loss did not improve from 1.03442
# Epoch 66/100
#  - 57s - loss: 1.4794 - acc: 0.4928 - val_loss: 1.6522 - val_acc: 0.4624
#
# Epoch 00066: val_loss did not improve from 1.03442
# Epoch 67/100
#  - 63s - loss: 1.4970 - acc: 0.4840 - val_loss: 1.4213 - val_acc: 0.4904
#
# Epoch 00067: val_loss did not improve from 1.03442
# Epoch 68/100
#  - 54s - loss: 1.5080 - acc: 0.4844 - val_loss: 1.5658 - val_acc: 0.4394
#
# Epoch 00068: val_loss did not improve from 1.03442
# Epoch 69/100
#  - 61s - loss: 1.4879 - acc: 0.4855 - val_loss: 2.0156 - val_acc: 0.3178
#
# Epoch 00069: val_loss did not improve from 1.03442
# Epoch 70/100
#  - 60s - loss: 1.4955 - acc: 0.4816 - val_loss: 1.8011 - val_acc: 0.4042
#
# Epoch 00070: val_loss did not improve from 1.03442
# Epoch 71/100
#  - 63s - loss: 1.4951 - acc: 0.4850 - val_loss: 1.5871 - val_acc: 0.4636
#
# Epoch 00071: val_loss did not improve from 1.03442
# Epoch 72/100
#  - 60s - loss: 1.5076 - acc: 0.4779 - val_loss: 1.6363 - val_acc: 0.4684
#
# Epoch 00072: val_loss did not improve from 1.03442
# Epoch 73/100
#  - 60s - loss: 1.5140 - acc: 0.4760 - val_loss: 1.4500 - val_acc: 0.5372
#
# Epoch 00073: val_loss did not improve from 1.03442
# Epoch 74/100
#  - 50s - loss: 1.5125 - acc: 0.4746 - val_loss: 1.5306 - val_acc: 0.5078
#
# Epoch 00074: val_loss did not improve from 1.03442
# Epoch 75/100
#  - 50s - loss: 1.5119 - acc: 0.4780 - val_loss: 1.4466 - val_acc: 0.5188
#
# Epoch 00075: val_loss did not improve from 1.03442
# Epoch 76/100
#  - 52s - loss: 1.5311 - acc: 0.4731 - val_loss: 1.5521 - val_acc: 0.4538
#
# Epoch 00076: val_loss did not improve from 1.03442
# Epoch 77/100
#  - 52s - loss: 1.5235 - acc: 0.4710 - val_loss: 1.5899 - val_acc: 0.4678
#
# Epoch 00077: val_loss did not improve from 1.03442
# Epoch 78/100
#  - 52s - loss: 1.5279 - acc: 0.4734 - val_loss: 1.8454 - val_acc: 0.3522
#
# Epoch 00078: val_loss did not improve from 1.03442
# Epoch 79/100
#  - 52s - loss: 1.5365 - acc: 0.4716 - val_loss: 1.8759 - val_acc: 0.3430
#
# Epoch 00079: val_loss did not improve from 1.03442
# Epoch 80/100
#  - 51s - loss: 1.5401 - acc: 0.4676 - val_loss: 1.5899 - val_acc: 0.4262
#
# Epoch 00080: val_loss did not improve from 1.03442
# Epoch 81/100
#  - 51s - loss: 1.5414 - acc: 0.4628 - val_loss: 1.5407 - val_acc: 0.4588
#
# Epoch 00081: val_loss did not improve from 1.03442
# Epoch 82/100
#  - 51s - loss: 1.5502 - acc: 0.4661 - val_loss: 1.8213 - val_acc: 0.3568
#
# Epoch 00082: val_loss did not improve from 1.03442
# Epoch 83/100
#  - 52s - loss: 1.5456 - acc: 0.4692 - val_loss: 1.5744 - val_acc: 0.4832
#
# Epoch 00083: val_loss did not improve from 1.03442
# Epoch 84/100
#  - 51s - loss: 1.5527 - acc: 0.4653 - val_loss: 1.5914 - val_acc: 0.4796
#
# Epoch 00084: val_loss did not improve from 1.03442
# Epoch 85/100
#  - 58s - loss: 1.5375 - acc: 0.4679 - val_loss: 1.6364 - val_acc: 0.4714
#
# Epoch 00085: val_loss did not improve from 1.03442
# Epoch 86/100
#  - 64s - loss: 1.5469 - acc: 0.4641 - val_loss: 1.4142 - val_acc: 0.5074
#
# Epoch 00086: val_loss did not improve from 1.03442
# Epoch 87/100
#  - 57s - loss: 1.5421 - acc: 0.4656 - val_loss: 1.6395 - val_acc: 0.4532
#
# Epoch 00087: val_loss did not improve from 1.03442
# Epoch 88/100
#  - 60s - loss: 1.5467 - acc: 0.4641 - val_loss: 1.6178 - val_acc: 0.4750
#
# Epoch 00088: val_loss did not improve from 1.03442
# Epoch 89/100
#  - 65s - loss: 1.5558 - acc: 0.4633 - val_loss: 1.8191 - val_acc: 0.3808
#
# Epoch 00089: val_loss did not improve from 1.03442
# Epoch 90/100
#  - 52s - loss: 1.5605 - acc: 0.4609 - val_loss: 1.6598 - val_acc: 0.4470
#
# Epoch 00090: val_loss did not improve from 1.03442
# Epoch 91/100
#  - 51s - loss: 1.5505 - acc: 0.4638 - val_loss: 1.6359 - val_acc: 0.4520
#
# Epoch 00091: val_loss did not improve from 1.03442
# Epoch 92/100
#  - 53s - loss: 1.5620 - acc: 0.4590 - val_loss: 1.7098 - val_acc: 0.4306
#
# Epoch 00092: val_loss did not improve from 1.03442
# Epoch 93/100
#  - 55s - loss: 1.5662 - acc: 0.4555 - val_loss: 1.5190 - val_acc: 0.5142
#
# Epoch 00093: val_loss did not improve from 1.03442
# Epoch 94/100
#  - 60s - loss: 1.5622 - acc: 0.4545 - val_loss: 1.7211 - val_acc: 0.4084
#
# Epoch 00094: val_loss did not improve from 1.03442
# Epoch 95/100
#  - 59s - loss: 1.5794 - acc: 0.4528 - val_loss: 1.7411 - val_acc: 0.3688
#
# Epoch 00095: val_loss did not improve from 1.03442
# Epoch 96/100
#  - 60s - loss: 1.5820 - acc: 0.4522 - val_loss: 1.5315 - val_acc: 0.5120
#
# Epoch 00096: val_loss did not improve from 1.03442
# Epoch 97/100
#  - 59s - loss: 1.5687 - acc: 0.4516 - val_loss: 1.7721 - val_acc: 0.3880
#
# Epoch 00097: val_loss did not improve from 1.03442
# Epoch 98/100
#  - 53s - loss: 1.5897 - acc: 0.4447 - val_loss: 1.6818 - val_acc: 0.4046
#
# Epoch 00098: val_loss did not improve from 1.03442
# Epoch 99/100
#  - 52s - loss: 1.5998 - acc: 0.4434 - val_loss: 1.7708 - val_acc: 0.4078
#
# Epoch 00099: val_loss did not improve from 1.03442
# Epoch 100/100
#  - 52s - loss: 1.5765 - acc: 0.4489 - val_loss: 1.7083 - val_acc: 0.4182
#
# Epoch 00100: val_loss did not improve from 1.03442

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6696

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
